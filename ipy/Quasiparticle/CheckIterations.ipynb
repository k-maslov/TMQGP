# %%
from numpy import *
import h5py

# %%
folder = '/home/const/Numerics/TMQGP/ipy/TMQGP/test/newG2/170/'

# %%
irange = range(0, 9)

# %%
dfs = [h5py.File(folder + 'iter_%i.hdf5'%i) for i in irange]

# %%
df = dfs[6]

# %%
erange = linspace(-5, 5, 101)

# %%
erange2b = linspace(-5, 5, 201)

# %%
df['Q'].keys()
# Out:
# <KeysViewHDF5 ['G', 'S']>

# %%
plt.plot(erange, real(df['Q']['G'][:, 0]), marker='.')
plt.plot(erange, imag(df['Q']['G'][:, 0]), marker='.')

# %%
plt.plot(erange2b, imag(df['TM']['qa1']['0'][:, 0]))

# %%
df['G2'].keys()
# Out:
# <KeysViewHDF5 ['AA', 'AQ', 'QA', 'QQ']>

# %%
plt.plot(erange2b, imag(df['G2']['QQ'][:, 0]))
plt.axhline(0)

# %%
plt.plot(erange, imag(df['Q']['S'][:, 0]), marker='.')
plt.axhline(0)
