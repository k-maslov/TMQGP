# %%
import TMQGP as tm
from numpy import *

# %%
import QuarkTM

# %%
qrange = linspace(0, 5, 51)
erange = linspace(-5, 5, 201)

q = QuarkTM.Particle(0.5, qrange, erange, eps=0.1)

# %%
plt.plot(erange, q.Rtab[:, 0])

# %%
G = 4.
L = 1.7

# %%
ch = QuarkTM.Channel(q, q, 0.2, G=G, L=L)

# %%
ch.populate_T()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
ch.TM = ch.TM/3

# %%
plt.plot(erange, imag(ch.TM[:, 0]))
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %%
ch.populate_S(only0=1)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.plot(erange, 3*ch.ImS[:, 0])

plt.xlim(0, 1)
# Out:
# (0.0, 1.0)
