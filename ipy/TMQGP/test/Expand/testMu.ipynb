#    0.20406039-2.08224883e-03j   0.20199959-2.04039992e-03j
#    0.19998   -1.99980002e-03j   0.19800039-1.96039992e-03j
#    0.19605959-1.92215281e-03j   0.19415646-1.88501414e-03j
#    0.19228991-1.84894148e-03j   0.19045892-1.81389443e-03j
#    0.18866245-1.77983448e-03j   0.18689956-1.74672489e-03j
#    0.18516931-1.71453065e-03j   0.1834708 -1.68321831e-03j
#    0.18180316-1.65275597e-03j   0.18016556-1.62311313e-03j
#    0.17855719-1.59426066e-03j   0.17697729-1.56617071e-03j
#    0.1754251 -1.53881665e-03j   0.17389989-1.51217299e-03j
#    0.17240098-1.48621535e-03j   0.17092768-1.46092038e-03j
#    0.16947935-1.43626571e-03j   0.16805536-1.41222991e-03j
#    0.16665509-1.38879244e-03j   0.16527797-1.36593362e-03j
#    0.16392341-1.34363453e-03j   0.16259088-1.32187707e-03j
#    0.16127983-1.30064382e-03j   0.15998976-1.27991809e-03j
#    0.15872016-1.25968382e-03j   0.15747055-1.23992560e-03j
#    0.15624046-1.22062862e-03j]
# /home/const/Numerics/TMQGP/py/QuarkTM.py:128: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / (E - self.om0(q) + 1j*self.eps*(1 + np.tanh((E - self.mu)/0.001))/2 + mu)
# /home/const/Numerics/TMQGP/py/QuarkTM.py:128: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 / (E - self.om0(q) + 1j*self.eps*(1 + np.tanh((E - self.mu)/0.001))/2 + mu)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 pt1 = QuarkTM.Particle(0.6, qrange, erange, mu=2)
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:71, in Particle.__init__(self, m, qrange, erange, stat, eps, d, propagator, Gtab, mu, S, S_lim)
#      69     plt.plot(erange, np.imag(ge))
#      70     print(ge)
# ---> 71 iIm = Akima1DInterpolator(erange, np.imag(ge))
#      72 iImS = Akima1DInterpolator(erange, np.imag(s))
#      73 # plt.plot(erange, iIm(erange))
#      74
#      75 # break
#
# File /usr/lib/python3.11/site-packages/scipy/interpolate/_cubic.py:420, in Akima1DInterpolator.__init__(self, x, y, axis)
#     417 def __init__(self, x, y, axis=0):
#     418     # Original implementation in MATLAB by N. Shamsundar (BSD licensed), see
#     419     # https://www.mathworks.com/matlabcentral/fileexchange/1814-akima-interpolation
# --> 420     x, dx, y, axis, _ = prepare_input(x, y, axis)
#     422     # determine slopes between breakpoints
#     423     m = np.empty((x.size + 3, ) + y.shape[1:])
#
# File /usr/lib/python3.11/site-packages/scipy/interpolate/_cubic.py:54, in prepare_input(x, y, axis, dydx)
#      52     raise ValueError("`x` must contain only finite values.")
#      53 if not np.all(np.isfinite(y)):
# ---> 54     raise ValueError("`y` must contain only finite values.")
#      56 if dydx is not None and not np.all(np.isfinite(dydx)):
#      57     raise ValueError("`dydx` must contain only finite values.")
#
# ValueError: `y` must contain only finite values.

# %%
any(isinf(pt1.Gtab))
# Out:
# False

# %%
plt.plot(erange, imag(pt1.S[:, 0]))

# %%
plt.plot(erange, imag(pt.Gtab[:, 0]))
plt.plot(erange, imag(pt1.Gtab[:, 0]))

plt.plot(erange, [pt.iImG(0, e) for e in erange])
plt.plot(erange, [pt1.iImG(0, e) for e in erange])
