# %%
from numpy import *
import h5py

# %%
Tlabel = '400'

# %%
data = h5py.File(f'mu1/data_single_{Tlabel}.hdf5', 'r')

# %%
data0 = h5py.File(f'./mu0/data_single_{Tlabel}.hdf5', 'r')

# %%
erange = linspace(-5, 5, 101)

# %%
erange = data.attrs['erange']

# %%
plt.plot(erange, -1/pi*imag(data['Q']['G'][:, 0]))
plt.plot(erange, -1/pi*imag(data0['Q']['G'][:, 0]), ls=':')
plt.plot(erange, -1/pi*imag(data['A']['G'][:, 0]), ls='--')
# plt.plot(erange, -1/pi*imag(data2['A']['G'][:, 0]), ls='--')

# %%
plt.plot(erange, -1/pi*imag(data['Q']['S'][:, 0]))
plt.plot(erange, -1/pi*imag(data0['Q']['S'][:, 0]), ls=':')
plt.plot(erange, -1/pi*imag(data['A']['S'][:, 0]), ls='--')

# %%
plt.plot(erange, -1/pi*imag(data['G']['G'][:, 0]))
plt.plot(erange, -1/pi*imag(data0['G']['G'][:, 0]), ls=':')
# plt.plot(erange, data['A']['R'][:, 0])

# %%
data['S'].keys()
# Out:
# <KeysViewHDF5 ['AA', 'AG', 'AQ', 'GA', 'GG', 'GQ', 'QA', 'QG', 'QQ']>

# %%
# plt.plot(erange, data['Q']['S'][:, 0])
plt.plot(erange, imag(data0['S']['QQ'][:, 0]), ls=':')
plt.plot(erange, imag(data['S']['QQ'][:, 0]))
plt.plot(erange, imag(data['S']['QA'][:, 0]))

plt.plot(erange, imag(data['S']['QQ'][:, 0]) + imag(data['S']['QA'][:, 0]))

# plt.plot(erange, data0['Q']['S'][:, 0], ls=':')

# %%
# plt.plot(erange, data['Q']['S'][:, 0])
plt.plot(erange, imag(data['S']['GQ'][:, 0]))
plt.plot(erange, imag(data['S']['GA'][:, 0]))

plt.plot(erange, (imag(data['S']['GQ'][:, 0]) + imag(data['S']['GA'][:, 0])), ls='--')
plt.plot(erange, imag(data0['S']['GQ'][:, 0]), ls=':')

# plt.plot(erange, data0['Q']['S'][:, 0], ls=':')

# %%
# plt.plot(erange, data['Q']['S'][:, 0])

plt.plot(erange, imag(data['S']['GQ'][:, 0]))
# plt.plot(erange, imag(data['S']['GA'][:, 0]))
plt.plot(erange, imag(data0['S']['GQ'][:, 0]), ls=':')
# plt.plot(erange, (imag(data['S']['GQ'][:, 0]) + imag(data['S']['GA'][:, 0])), ls='--')

# plt.plot(erange, data0['Q']['S'][:, 0], ls=':')

# %%
data['TM']['ga3']['0'][:, 0]
# Out:
# array([-388.87627474-1.25934549e-04j, -397.25089786-2.10536732e-04j,
#        -397.37984418-3.50480288e-04j, -397.51294702-6.15037587e-04j,
#        -397.65024519-1.08076477e-03j, -397.79187399-1.56366514e-03j,
#        -397.93814832-2.01388863e-03j, -398.08936112-2.42369542e-03j,
#        -398.24579294-2.83441729e-03j, -398.4076945 -3.24397602e-03j,
#        -398.5753614 -3.60941521e-03j, -398.7491712 -3.88754734e-03j,
#        -398.92956166-4.09495623e-03j, -399.11694255-4.32862063e-03j,
#        -399.31167572-4.65016010e-03j, -399.51414171-5.06484940e-03j,
#        -399.72480526-5.54703313e-03j, -399.94418672-6.09715973e-03j,
#        -400.17281631-6.71941234e-03j, -400.41125546-7.35542079e-03j,
#        -400.66027136-7.90218965e-03j, -400.92069785-8.32178192e-03j,
#        -401.1934916 -8.72904439e-03j, -401.47952887-9.28153653e-03j,
#        -401.77967567-1.00362617e-02j, -402.09494584-1.09089529e-02j,
#        -402.42663465-1.17951241e-02j, -402.77623871-1.27495666e-02j,
# ...

# %%
data0['TM']['gq3']['0'][:, 0]
# Out:
# array([-388.87627474-5.25121147e-04j, -396.93836692-8.28805432e-04j,
#        -397.07023309-1.34265804e-03j, -397.20657486-2.37793585e-03j,
#        -397.34709956-3.87377391e-03j, -397.49200412-5.25614154e-03j,
#        -397.64184755-6.43082801e-03j, -397.79707037-7.37197971e-03j,
#        -397.95822768-8.26662479e-03j, -398.12545478-9.27411694e-03j,
#        -398.29896051-1.03885233e-02j, -398.47910166-1.14182729e-02j,
#        -398.66644254-1.22067973e-02j, -398.8616929 -1.28525485e-02j,
#        -399.06538711-1.36233328e-02j, -399.27784241-1.46674690e-02j,
#        -399.49948135-1.58392402e-02j, -399.73102077-1.69780765e-02j,
#        -399.97337955-1.80941853e-02j, -400.22741755-1.94564432e-02j,
#        -400.49374288-2.12867328e-02j, -400.77297901-2.34378803e-02j,
#        -401.06617812-2.55460195e-02j, -401.37487773-2.74625555e-02j,
#        -401.70067628-2.95193462e-02j, -402.04484737-3.21397137e-02j,
#        -402.40854999-3.53297098e-02j, -402.79347651-3.86402987e-02j,
# ...

# %%
# plt.plot(erange, data['Q']['S'][:, 0])

plt.plot(erange, imag(data['TMtot']['GQ'][:, 0]))
# plt.plot(erange, imag(data['S']['GA'][:, 0]))
plt.plot(erange, imag(data0['TMtot']['GQ'][:, 0]), ls=':')
# plt.plot(erange, (imag(data['S']['GQ'][:, 0]) + imag(data['S']['GA'][:, 0])), ls='--')

# plt.plot(erange, data0['Q']['S'][:, 0], ls=':')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[320], line 3
#       1 # plt.plot(erange, data['Q']['S'][:, 0])
# ----> 3 plt.plot(erange, imag(data['TMtot']['GQ'][:, 0]))
#       4 # plt.plot(erange, imag(data['S']['GA'][:, 0]))
#       5 plt.plot(erange, imag(data0['TMtot']['GQ'][:, 0]), ls=':')
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /usr/lib/python3.11/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# ...

# %%
plt.plot(erange, imag(data['TM']['qa1']['0'][:, 0]))
# plt.plot(erange, imag(data['S']['GA'][:, 0]))
plt.plot(erange, imag(data0['TM']['qa1']['0'][:, 0]), ls=':')
