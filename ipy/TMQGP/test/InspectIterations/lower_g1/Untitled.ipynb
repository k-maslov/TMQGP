# %%
import h5py
from numpy import *

# %%
df = h5py.File('data_single_170_lo2.hdf5')

# %%
erange = df.attrs['erange']

# %%
plt.plot(erange, imag(df['TM']['qa1']['1'][:, 1]))

plt.xlim(0, 1.4)
# Out:
# (0.0, 1.4)

# %%
plt.plot(erange, imag(df['TM']['qa1']['0'][:, 1]))

plt.xlim(0, 1.4)
# Out:
# (0.0, 1.4)

# %%
plt.plot(erange, imag(1 / (1 - (df['X']['qa1']['1'][:, 10]))))
plt.xlim(1, 2)
# Out:
# (1.0, 2.0)
