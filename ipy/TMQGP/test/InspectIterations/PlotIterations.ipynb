# %%
from numpy import *
import h5py

# %%
fs = [h5py.File('400/iter_%i.hdf5'%i) for i in range(24)]

# %%
f = fs[0]

# %%
f['0']['Q'].keys()
# Out:
# <KeysViewHDF5 ['G', 'S']>

# %%
erange = linspace(-5, 5, 101)

# %%
for i, f in list(zip(range(25), fs))[::7]:
    plt.plot(erange, imag(f['%i'%i]['Q']['G'][:, 0]))

# %% [markdown]
# ### Test calculation of delta

# %%
i1 = 22
i2 = 23

R1 = -2*imag(fs[i1]['%i'%i1]['Q']['G'])
R2 = -2*imag(fs[i2]['%i'%i2]['Q']['G'])

Diff = abs(R1 - R2)

argmax(Diff)

plt.plot(Diff.flatten())

# %%
R1 = -2*imag(fs[i1]['%i'%i1]['Q']['G'])
R2 = -2*imag(fs[i2]['%i'%i2]['Q']['G'])

Diff = abs(R1 - R2)

plt.plot(Diff.flatten())

max(Diff), argmax(Diff)

# i1 = 1
# i2 = 2

# R1 = -2*imag(fs[i1]['%i'%i1]['Q']['S'])
# R2 = -2*imag(fs[i2]['%i'%i2]['Q']['S'])

# Diff = abs(R1 - R2)

# max(Diff), argmax(Diff)

# plt.plot(Diff.flatten())
# Out:
# (0.6347546694646908, 1542)

# %%
1542 - 1542//21 * 21
# Out:
# 9

# %%
plt.plot(Diff[:, 9])

# %%
plt.plot(erange, R1[:, 9])
plt.plot(erange, R2[:, 9])

# plt.semilogy()
# plt.ylim(0, 1e-3)

# %%
plt.plot(R1[:, 0])
plt.plot(R2[:, 0])
