# %%
import TMQGP as tm
import QuarkTM
from numpy import *

# %%
erange = linspace(-5, 5, 201)
qrange = linspace(0, 5, 51)

# %%
q = QuarkTM.Particle(0.5, qrange, erange, stat='f')

# %%
ch = QuarkTM.Channel(q, q, 0.2, G=9, L=0.6)

ch.populate_T()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
plt.plot(erange, imag(ch.TM[:, 0]))
plt.axvline(2*q.m, ls=':', c='black')

# plt.ylim(-100, 100)
