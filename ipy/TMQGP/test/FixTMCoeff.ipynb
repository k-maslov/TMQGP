# %%
import TMQGP as tm
import QuarkTM
from numpy import *

# %%
erange = linspace(-5, 5, 801)
qrange = linspace(0, 5, 151)

# %%
quark_0 = QuarkTM.Particle(0.5, qrange, erange, eps=2e-2)

# %%
T = 0.15
G = 8.5
L = 0.5
screen = 1.5

# %%
ch_quark_test = QuarkTM.Channel(quark_0, quark_0, T, G=G, screen=screen)
ch_quark_test.populate_T()
# Out:
#   0%|          | 0/801 [00:00<?, ?it/s]

# %%
plt.plot(erange, imag(ch_quark_test.TM[:, 0]))
plt.axvline(2*quark_0.m, ls=':', c='black')

# plt.ylim(-1, 1)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
plt.plot(erange, imag(ch_quark_test.X[:, 0]))
plt.plot(erange, real(ch_quark_test.X[:, 0]))

# %%
plt.plot(ch_quark_test.erange, imag(ch_quark_test.TM[:, 0]))
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)
