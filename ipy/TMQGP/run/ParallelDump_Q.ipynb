# %%
from numpy import *
from scipy import signal
from scipy.integrate import quad
import TMQGP as tm
import tqdm.notebook as tqdm
from QuarkTM import Particle, Channel

# %%
from syntax_sugar import pipe, END
from syntax_sugar import thread_syntax as t, process_syntax as p

NTHR = 14

# %%
erange = linspace(-5, 5, 201)
qrange = linspace(0, 5, 101)

# %%
mQ = 0.5

# %%
quark_0 = Particle(mQ, qrange, erange, eps=2e-2)
gluon_0 = Particle(1., qrange, erange, eps=2e-2, stat='b', d=16)
gluon_0 = Particle(1., qrange, erange, eps=2e-2, stat='b', d=16)

# %%
T = 0.15
G = 9
L = 0.4
screen = 1.5

# %% [markdown]
# ## Check the resonance position

# %%
ch_quark_test = Channel(quark_0, quark_0, T, G=G, L=L,screen=screen)

# %%
ch_quark_test.populate_T()
# ch_quark_test.populate_S()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
plt.plot(ch_quark_test.erange, imag(ch_quark_test.TM[:, 0]))
plt.xlim(0, 2)
plt.axvline(2*quark_0.m, ls=':', c='black')

# %%
ch_quark_test.populate_S()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ch_quark_test.populate_S()
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in Channel.populate_S(self)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in <listcomp>(.0)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in <listcomp>(.0)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/lib/TMQGP.py:1550, in sigma_ff(om, p, T, iImT, iImG)
#    1548 def sigma_ff(om, p, T, iImT, iImG):
#    1549     r"""sigma_ff(double om, double p, double T, Interpolator2D iImT, Interpolator2D iImG) -> double"""
# -> 1550     return _TMQGP.sigma_ff(om, p, T, iImT, iImG)
#
# KeyboardInterrupt:

# %%
gluon_0 = Particle(1.5, qrange, erange, eps=2e-2, stat='b', d=16)

# %%
ch_gluon_test = Channel(gluon_0, gluon_0, T, G=G, Fa=9/4,
                       da=1, ds=16, screen=screen)

# %%
ch_gluon_test.populate_T()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
plt.plot(ch_gluon_test.erange, imag(ch_gluon_test.TM[:, 0]))
# plt.xlim(0, 5)

# %%
ch_gluon_test.populate_S()
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 ch_gluon_test.populate_S()
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in Channel.populate_S(self)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in <listcomp>(.0)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/py/QuarkTM.py:395, in <listcomp>(.0)
#     392 def populate_S(self):
#     393     # print(self.func(0, 0, self.T, self.iImT, self.p_j.R))
#     394     if self.parallel < 2:
# --> 395         ress_cm = np.array([[self.func(e, q, self.T, self.iImT, self.p_j.R) for q in self.qrange]
#     396             for e in tqdm.tqdm(self.erange)])
#     397         self.ImS = ress_cm
#     398     else:
#
# File ~/Numerics/TMQGP/lib/TMQGP.py:1562, in sigma_bb2(om, p, T, iImT, iImG)
#    1560 def sigma_bb2(om, p, T, iImT, iImG):
#    1561     r"""sigma_bb2(double om, double p, double T, Interpolator2D iImT, Interpolator2D iImG) -> double"""
# -> 1562     return _TMQGP.sigma_bb2(om, p, T, iImT, iImG)
#
# KeyboardInterrupt:

# %%
plt.plot(ch_gluon_test.erange, ch_gluon_test.ImS[:, 0])

# %% [markdown]
# ## Run iterations in a cycle

# %%
erange = linspace(-5, 5, 201)
qrange = linspace(0, 5, 51)
quark_run = Particle(mQ, qrange, erange, eps=2e-2)
gluon_run = Particle(1., qrange, erange, eps=2e-2, stat='b', d=16)

# %%
chss = []
pts = []

delta = 1
T = 0.25

# %%
while delta > 1e-4:
#     ch_QQ = Channel(quark_run, quark_run, T, G=G, ds=4, da=1)
#     ch_GG = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=1, Fa=9/4)
#     ch_QG = Channel(quark_run, gluon_run, T, G=G, ds=6, da=3, Fa=9/8)
#     ch_GQ = Channel(gluon_run, quark_run, T, G=G, ds=6, da=3, Fa=9/8)
    
#     channels_Q = [ch_QQ, ch_QG]
#     channels_G = [ch_GG, ch_GQ]

    channels_Q = dict()
    
#     channels_Q['qq3'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=3, Fa=1/2, screen=screen)
#     channels_Q['qq6'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=6, Fa=1/4, screen=screen)
    channels_Q['qa1'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=1, Fa=1, screen=screen)
#     channels_Q['qa8'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=8, Fa=1/8, screen=screen)
    
#     channels_Q['qg3'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=3, Fa=9/8, screen=screen)
#     channels_Q['qg6'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=6, Fa=3/8, screen=screen)
#     channels_Q['qg15'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=15, Fa=3/8, screen=screen)
    
    channels_G = dict()
    
#     channels_G['gq3'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=3, Fa=9/8, screen=screen)
#     channels_G['gq6'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=6, Fa=3/8, screen=screen)
#     channels_G['gq15'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=15, Fa=3/8, screen=screen)
    
#     channels_G['gg1'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=1, Fa=9/4, screen=screen)
#     channels_G['gg16'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=16, Fa=9/8, screen=screen)
#     channels_G['gg27'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=27, Fa=3/4, screen=screen)
    
    channels = {k : c for k, c in list(channels_G.items()) + list(channels_Q.items())}
    
    for k, ch in channels.items():
        print(k)
        ch.populate_T()
        
        
        ############### dirty parallelization ################
        ress = []
        for q in tqdm.tqdm(ch.qrange):
            res = pipe(ch.erange) | p[lambda z: ch.func(z, q, ch.T, ch.iImT, ch.p_j.R)]*(NTHR//1) | END
            ress += [res]
            
        ress = array(ress).transpose()
        ch.ImS = ress
        
        ReSigmas = []

        for res in tqdm.tqdm(ress.transpose()):
            iImSigma = tm.Interpolator(ch.erange, np.ascontiguousarray(res), 'cubic')
            ReSigma = [tm.ReSigmaKK(e, iImSigma) for e in ch.erange]
            ReSigmas += [ReSigma]

        ch.ReS = np.array(ReSigmas).transpose()
        
        
        ############### Serial version #################
        
#         ch.populate_S()
#     break
        
    ImS_Q = sum([c.ds * c.da * c.ImS / c.p_i.d for k, c in channels_Q.items()], axis=0)
    ReS_Q = sum([c.ds * c.da * c.ReS / c.p_i.d for k, c in channels_Q.items()], axis=0)

    om0_k = np.array([quark_run.om0(quark_run.qrange) for e in quark_run.erange])
    arrE = np.array([quark_run.erange for q in quark_run.qrange]).transpose()

    G_Q_new = 1/(arrE - om0_k + 0*1j*quark_run.eps - (ReS_Q + 1j*ImS_Q))
    
#     quark_new = Particle(quark_run.m, qrange, erange, eps=2e-2, R=-2*imag(G_Q_new))
    quark_new = Particle(quark_run.m, qrange, erange, eps=2e-2, Gtab=G_Q_new)
    
    ImS_G = sum([c.ds * c.da *c.ImS / c.p_i.d for c in channels_G.values()],
           axis=0)
    ReS_G = sum([c.ds * c.da *c.ReS / c.p_i.d for c in channels_G.values()],
               axis=0)

    om0_k = np.array([gluon_run.om0(gluon_run.qrange) for e in gluon_run.erange])
    arrE = np.array([gluon_run.erange for q in gluon_run.qrange]).transpose()

#     G_G_new = 1/(arrE**2 - om0_k**2 + 2*1j*gluon_run.eps*arrE - (ReS_G + 1j*ImS_G))
    G_G_new = 1/(arrE - om0_k + 1j*gluon_run.eps - (ReS_G + 1j*ImS_G))
#     gluon_new = Particle(gluon_run.m, qrange, erange, eps=2e-2, stat='b', d=16, R=-2*imag(G_G_new))
    gluon_new = Particle(gluon_run.m, qrange, erange, eps=gluon_run.eps, stat='b', d=16, Gtab=G_G_new)
    
    chss += [[channels_Q, channels_G]]
    pts += [[quark_run, gluon_run]]
    
    delta = 0
    delta += sqrt(sum((quark_new.Rtab - quark_run.Rtab)**2)) / len(erange) / len(qrange)
    delta += sqrt(sum((gluon_new.Rtab - gluon_run.Rtab)**2)) / len(erange) / len(qrange)
    delta /= 2
    print(delta)
    
    quark_run = quark_new
    gluon_run = gluon_new
# Out:
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.04447004156868413
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.04294707822528579
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0371695701943176
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.033811333100986295
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.03141762283241501
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.025771738024476028
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.023488738758235476
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.018399371314865933
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.01621632558582271
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.012566175590621382
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.010768365896299292
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.008393055028021035
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Exception ignored in: <function _releaseLock at 0x7fd9e956b240>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 237, in _releaseLock
#     def _releaseLock():
#
# KeyboardInterrupt:
# Exception ignored in: <function _releaseLock at 0x7fd9e956b240>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 237, in _releaseLock
#     def _releaseLock():
#
# KeyboardInterrupt:
# Process ForkPoolWorker-10497:
# Process ForkPoolWorker-10498:
# Process ForkPoolWorker-10496:
# Process ForkPoolWorker-10490:
# Process ForkPoolWorker-10493:
# Process ForkPoolWorker-10491:
# Process ForkPoolWorker-10494:
# Process ForkPoolWorker-10495:
# Process ForkPoolWorker-10492:
# Process ForkPoolWorker-10499:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 224, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 422, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 387, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkPoolWorker-10501:
# Process ForkPoolWorker-10503:
# Process ForkPoolWorker-10502:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 41
#      39 ress = []
#      40 for q in tqdm.tqdm(ch.qrange):
# ---> 41     res = pipe(ch.erange) | p[lambda z: ch.func(z, q, ch.T, ch.iImT, ch.p_j.R)]*(NTHR//1) | END
#      42     ress += [res]
#      44 ress = array(ress).transpose()
#
# File /usr/lib/python3.11/site-packages/syntax_sugar/_pipe.py:115, in pipe.__or__(self, rhs)
#     112 def __or__(self, rhs):
#     113     if rhs is END:
#     114         # end of pipe
# --> 115         return self.action(self.data)
#     116     elif rhs is DEBUG:
#     117         # debug end of pipe
#     118         try:
#
# File /usr/lib/python3.11/site-packages/syntax_sugar/_composable.py:22, in compose.<locals>.<lambda>.<locals>.<lambda>(*ag, **kwag)
#      19 @infix
#      20 def compose(*args):
#      21     return reduce(lambda acc, fn:
# ---> 22         (lambda *ag, **kwag: acc(fn(*ag, **kwag))),
#      23     args)
#
# File /usr/lib/python3.11/site-packages/syntax_sugar/_pipe.py:70, in multiprocess(fn, poolsize, data)
#      69 def multiprocess(fn, poolsize, data):
# ---> 70     return multitask(fn, poolsize, data, Pool)
#
# File /usr/lib/python3.11/site-packages/syntax_sugar/_pipe.py:62, in multitask(fn, poolsize, data, pool_constructor)
#      61 def multitask(fn, poolsize, data, pool_constructor):
# ---> 62     with pool_constructor(poolsize) as p:
#      63         if not hasattr(data, '__iter__'):
#      64             data= [data]
#
# File /usr/lib/python3.11/site-packages/multiprocess/pool.py:739, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     738 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739     self.terminate()
#
# File /usr/lib/python3.11/site-packages/multiprocess/pool.py:657, in Pool.terminate(self)
#     655 util.debug('terminating pool')
#     656 self._state = TERMINATE
# --> 657 self._terminate()
#
# File /usr/lib/python3.11/site-packages/multiprocess/util.py:224, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     221 else:
#     222     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223               self._callback, self._args, self._kwargs)
# --> 224     res = self._callback(*self._args, **self._kwargs)
#     225 self._weakref = self._callback = self._args = \
#     226                 self._kwargs = self._key = None
#     227 return res
#
# File /usr/lib/python3.11/site-packages/multiprocess/pool.py:695, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     692 task_handler._state = TERMINATE
#     694 util.debug('helping task handler/workers to finish')
# --> 695 cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     697 if (not result_handler.is_alive()) and (len(cache) != 0):
#     698     raise AssertionError(
#     699         "Cannot have cache with result_hander not alive")
#
# File /usr/lib/python3.11/site-packages/multiprocess/pool.py:675, in Pool._help_stuff_finish(inqueue, task_handler, size)
#     671 @staticmethod
#     672 def _help_stuff_finish(inqueue, task_handler, size):
#     673     # task_handler may be blocked trying to put items on inqueue
#     674     util.debug('removing tasks from inqueue until task handler finished')
# --> 675     inqueue._rlock.acquire()
#     676     while task_handler.is_alive() and inqueue._reader.poll():
#     677         inqueue._reader.recv()
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 224, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 422, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 387, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Exception ignored in: <function Socket.__del__ at 0x7fd9e9c17d80>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/site-packages/zmq/sugar/socket.py", line 178, in __del__
#     def __del__(self):
#
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/site-packages/ipykernel/iostream.py", line 526, in flush
#     if not evt.wait(self.flush_timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/threading.py", line 622, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# Process ForkPoolWorker-10500:
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 224, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 422, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/site-packages/multiprocess/connection.py", line 387, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ##### Quark self-energies:

# %%
n_iter = -1

# %%
plt.plot(erange, pts[n_iter][0].Rtab[:, 0])

# %%
plt.plot(erange, imag(chss[n_iter][0]['qa1'].TM[:, 0]))
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %%
plt.plot(erange, chss[n_iter][0]['qa1'].ReS[:, 0])

# %%
plt.plot(erange, chss[n_iter][0]['qa1'].ImS[:, 0])
# plt.xlim(0, 1)

# %%
# chss[0][0]['qa1'].populate_S()
# plt.plot(erange, chss[0][0]['qa1'].ImS[:, 0])

# %%
res0 = array([ch.func(z, 0, ch.T, ch.iImT, ch.p_j.R) for z in erange])

# %%
plt.plot(erange, ress[:, 0])
plt.plot(erange, res0, ls='--')
plt.plot(erange, ch.ImS[:, 0], ls=':')

# %% [markdown]
# ##### Gluon self-energies

# %%
n_iter = 0

# %%
plt.plot(erange, pts[n_iter][1].Rtab[:, 0])

# plt.ylim(-1, 1)

# %%
plt.plot(erange, imag(chss[n_iter][1]['gq3'].TM[:, 0]))
# plt.xlim(0, 2)

# %%
plt.plot(erange, chss[n_iter][1]['gg1'].ImS[:, 0])

# %%
Rtab

# %% [markdown]
# ##### ====

# %%
chss += [[channels_Q, channels_G]]

# %%
for k, c in chss[0][1].items():
    plt.plot(erange, imag(c.TM[:, 0]), label=k)
    
plt.legend()
plt.ylim(-2000, 0)
# Out:
# (-2000.0, 0.0)

# %%
for k, c in chss[-1][1].items():
    plt.plot(erange, c.ImS[:, 0], label=k)
    
plt.legend()

# plt.xlim(-0.5, 0.5)

# %%
for pt in pts:
    plt.plot(erange, pt[0].Rtab[:, 0])
    print(trapz(pt[0].Rtab[:, 0], x=erange)/2/pi)
    
plt.xlim(-1, 5)
# plt.ylim(0, 30)
# Out:
# 1.1737009865632435
# 1.1598540736312284
# 1.1705497105598273
# 1.1714647582213435
# 1.17147346593816
# 1.1714712100688796
# 1.1714723229767983
# 1.1714723301271288
# (-1.0, 5.0)

# %%
for i, pt in enumerate(pts):
    plt.plot(erange, pt[1].Rtab[:, 0], marker='.', lw=1, label=i)
    print(trapz(pt[1].Rtab[:, 0], x=erange)/2/pi)
    
plt.legend()

plt.xlim(0, 3)
# Out:
# 1.1736086664353786
# 0.0965173491227193
# 0.14900714816332875
# 6.7472641960734085
# 6.952906579303587
# 6.421205638858628
# 7.163748695538224
# 6.166601373204766
# (0.0, 3.0)

# %%
plt.plot(chss[3][1]['gg1'].ImS[:, 0], lw=1, marker='.')

# %%
[plt.plot(erange, (c.ImS[:, 0]), label=k) for k, c in chss[-1][1].items()]
plt.legend()

# %%
out_folder = 'output/QuarkOnly/'

cQ, cG = chss[0]


for k, c in cQ.items():
    np.savetxt(out_folder + 'Q_TM_'+k+'_T=%.3f.dat'%T, c.TM)
    np.savetxt(out_folder + 'Q_ImS_'+k+'_T=%.3f.dat'%T, c.ImS)
    np.savetxt(out_folder + 'Q_ReS_'+k+'_T=%.3f.dat'%T, c.ReS)

for k, c in cG.items():
    np.savetxt(out_folder + 'G_TM_'+k+'_T=%.3f.dat'%T, c.TM)
    np.savetxt(out_folder + 'G_ImS_'+k+'_T=%.3f.dat'%T, c.ImS)
    np.savetxt(out_folder + 'G_ReS_'+k+'_T=%.3f.dat'%T, c.ReS)
        
    

np.savetxt(out_folder + 'Q_Rho_T=%.3f.dat'%T, pts[-1][0].Rtab)
np.savetxt(out_folder + 'G_Rho_T=%.3f.dat'%T, pts[-1][1].Rtab)

np.savetxt(out_folder + 'Q_G_T=%.3f.dat'%T, pts[-1][0].Gtab)
np.savetxt(out_folder + 'G_G_T=%.3f.dat'%T, pts[-1][1].Gtab)

np.savetxt(out_folder + 'erange_T=%.3f.dat'%T, erange)
np.savetxt(out_folder + 'qrange_T=%.3f.dat'%T, qrange)

# %%
channels_Q.keys()
# Out:
# dict_keys(['qq3', 'qq6', 'qa1', 'qa8', 'qg3', 'qg6', 'qg15'])

# %% [markdown]
# ## Iterate over temperatures too

# %%
erange = linspace(-5, 5, 201)
qrange = linspace(0, 5, 51)

eps = 2e-2
quark_run = Particle(mQ, qrange, erange, eps=eps)
gluon_run = Particle(1.5, qrange, erange, eps=eps, stat='b', d=16)

# %%
import os

# %%
out_folder = 'output/QuarkOnly_X_1ch_test4pi_onshell/'
if not os.path.exists(out_folder):
    os.mkdir(out_folder)

# %%
Trange = arange(0.2, 0.65, 0.05)

# %%
quark_run.d
# Out:
# 6

# %%
for T in Trange:

    chss = []
    pts = []

    delta = 1

    while delta > 1e-3:
    #     ch_QQ = Channel(quark_run, quark_run, T, G=G, ds=4, da=1)
    #     ch_GG = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=1, Fa=9/4)
    #     ch_QG = Channel(quark_run, gluon_run, T, G=G, ds=6, da=3, Fa=9/8)
    #     ch_GQ = Channel(gluon_run, quark_run, T, G=G, ds=6, da=3, Fa=9/8)

    #     channels_Q = [ch_QQ, ch_QG]
    #     channels_G = [ch_GG, ch_GQ]

        channels_Q = dict()

#         channels_Q['qq3'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=3, Fa=1/2, screen=screen)
#         channels_Q['qq6'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=6, Fa=1/4, screen=screen)
        channels_Q['qa1'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=1, Fa=1, screen=screen)
#         channels_Q['qa8'] = Channel(quark_run, quark_run, T, G=G, ds=4, da=8, Fa=1/8, screen=screen)

#         channels_Q['qg3'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=3, Fa=9/8, screen=screen)
    #     channels_Q['qg6'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=6, Fa=3/8, screen=screen)
    #     channels_Q['qg15'] = Channel(quark_run, gluon_run, T, G=G, ds=6, da=15, Fa=3/8, screen=screen)

        channels_G = dict()

#         channels_G['gq3'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=3, Fa=9/8, screen=screen)
    #     channels_G['gq6'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=6, Fa=3/8, screen=screen)
    #     channels_G['gq15'] = Channel(gluon_run, quark_run, T, G=G, ds=6, da=15, Fa=3/8, screen=screen)

#         channels_G['gg1'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=1, Fa=9/4, screen=screen)
    #     channels_G['gg16'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=16, Fa=9/8, screen=screen)
    #     channels_G['gg27'] = Channel(gluon_run, gluon_run, T, G=G, ds=9, da=27, Fa=3/4, screen=screen)

        channels = {k : c for k, c in list(channels_G.items()) + list(channels_Q.items())}

        for k, ch in channels.items():
            np.savetxt(out_folder + f'{k}_vq.dat', ch.v(ch.qrange))
            np.savetxt(out_folder + f'{k}_weights', array([ch.ds, ch.da, ch.Fa]))
        
        for k, ch in channels.items():
            print(k)
            ch.populate_T()
            
            

            ############### dirty parallelization ################
            ress = []
            for q in tqdm.tqdm(ch.qrange):
                if ch.func != tm.sigma_ff_onshell:
                    res = pipe(ch.erange) | p[lambda z: ch.func(z, q, ch.T, ch.iImT, ch.p_j.R)]*(NTHR//1) | END
                    ress += [res]
                else:
                    eps1 = tm.Interpolator(ch.qrange, ch.p_i.om0(ch.qrange), 'linear')
                    eps2 = tm.Interpolator(ch.qrange, ch.p_j.om0(ch.qrange), 'linear')
                    res = pipe(ch.erange) | p[lambda z: ch.func(z, q, ch.T, ch.iImT, 
                                                                ch.p_j.R, eps1, eps2)]*(NTHR//1) | END
                    ress += [res]

            ress = array(ress).transpose()
            ch.ImS = ress

            ReSigmas = []

            for res in tqdm.tqdm(ress.transpose()):
                iImSigma = tm.Interpolator(ch.erange, np.ascontiguousarray(res), 'cubic')
                ReSigma = [tm.ReSigmaKK(e, iImSigma) for e in ch.erange]
                ReSigmas += [ReSigma]

            ch.ReS = np.array(ReSigmas).transpose()


            ############### Serial version #################

    #         ch.populate_S()
    #     break

        ImS_Q = sum([c.ds * c.da * c.ImS / c.p_i.d for k, c in channels_Q.items()], axis=0)
        ReS_Q = sum([c.ds * c.da * c.ReS / c.p_i.d for k, c in channels_Q.items()], axis=0)

        om0_k = np.array([quark_run.om0(quark_run.qrange) for e in quark_run.erange])
        arrE = np.array([quark_run.erange for q in quark_run.qrange]).transpose()

        G_Q_new = 1/(arrE - om0_k + 0*1j*quark_run.eps - (ReS_Q + 1j*ImS_Q))

    #     quark_new = Particle(quark_run.m, qrange, erange, eps=2e-2, R=-2*imag(G_Q_new))
        quark_new = Particle(quark_run.m, qrange, erange, eps=quark_run.eps, Gtab=G_Q_new)
        
        quark_new.S = ReS_Q + 1j*ImS_Q
        
        ImS_G = sum([c.ds * c.da *c.ImS / c.p_i.d for c in channels_G.values()],
               axis=0)
        
        ReS_G = sum([c.ds * c.da *c.ReS / c.p_i.d for c in channels_G.values()],
               axis=0)

        om0_k = np.array([gluon_run.om0(gluon_run.qrange) for e in gluon_run.erange])
        arrE = np.array([gluon_run.erange for q in gluon_run.qrange]).transpose()

    #     G_G_new = 1/(arrE**2 - om0_k**2 + 2*1j*gluon_run.eps*arrE - (ReS_G + 1j*ImS_G))
        G_G_new = 1/(arrE - om0_k + 1j*gluon_run.eps - (ReS_G + 1j*ImS_G))
    #     gluon_new = Particle(gluon_run.m, qrange, erange, eps=2e-2, stat='b', d=16, R=-2*imag(G_G_new))
        gluon_new = Particle(gluon_run.m, qrange, erange, eps=gluon_run.eps, stat='b', d=16, Gtab=G_G_new)
        
        gluon_new.S = ReS_G + 1j*ImS_G
        
        chss += [[channels_Q, channels_G]]
        pts += [[quark_run, gluon_run]]

        delta = 0
        delta += sqrt(sum((quark_new.Rtab - quark_run.Rtab)**2)) / len(erange) / len(qrange)
#         delta += sqrt(sum((gluon_new.Rtab - gluon_run.Rtab)**2)) / len(erange) / len(qrange)
        delta /= 2
        print(delta)

        quark_run = quark_new
        gluon_run = gluon_new

    cQ, cG = chss[-1]

    for k, c in cQ.items():
        np.savetxt(out_folder + 'Q_TM_'+k+'_T=%.3f.dat'%T, c.TM)
        np.savetxt(out_folder + 'Q_X_'+k+'_T=%.3f.dat'%T, c.X)
        np.savetxt(out_folder + 'Q_ImS_'+k+'_T=%.3f.dat'%T, c.ImS)
        np.savetxt(out_folder + 'Q_ReS_'+k+'_T=%.3f.dat'%T, c.ReS)

    for k, c in cG.items():
        np.savetxt(out_folder + 'G_TM_'+k+'_T=%.3f.dat'%T, c.TM)
#         np.savetxt(out_folder + 'G_X_'+k+'_T=%.3f.dat'%T, c.X)
        np.savetxt(out_folder + 'G_ImS_'+k+'_T=%.3f.dat'%T, c.ImS)
        np.savetxt(out_folder + 'G_ReS_'+k+'_T=%.3f.dat'%T, c.ReS)



    np.savetxt(out_folder + 'Q_Rho_T=%.3f.dat'%T, pts[-1][0].Rtab)
    np.savetxt(out_folder + 'G_Rho_T=%.3f.dat'%T, pts[-1][1].Rtab)

    np.savetxt(out_folder + 'Q_G_T=%.3f.dat'%T, pts[-1][0].Gtab)
    np.savetxt(out_folder + 'G_G_T=%.3f.dat'%T, pts[-1][1].Gtab)
    
    np.savetxt(out_folder + 'Q_S_T=%.3f.dat'%T, pts[-1][0].S)
#     np.savetxt(out_folder + 'G_S_T=%.3f.dat'%T, pts[-1][1].S)

    np.savetxt(out_folder + 'erange_T=%.3f.dat'%T, erange)
    np.savetxt(out_folder + 'qrange_T=%.3f.dat'%T, qrange)
# Out:
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.03609658451597463
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.022765657272499348
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.009539367748193563
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.00398454484588037
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0018262962296457864
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0010031097237670887
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0008199612991842786
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.006775530446245716
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.003616655730501852
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.00186963927030038
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0009577931833644016
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.005621216869682892
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0027761613785036447
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0014424169228976734
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0007964149235353799
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.004754857781659575
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.001317191582650076
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0004971184601824176
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0032088204447743613
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0005215494435530097
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0020201692969783027
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0016311325604871205
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0011053813770313223
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0005353224709890638
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.001465064705457215
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0021635803484645723
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0012132050726234918
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.00048712713119023675
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0016917855107018414
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0024768086758103153
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0011530890433116717
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0003690731224222105
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.002189692166400057
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.002492244808978549
# qa1
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# 0.0009661556288808207

# %%
any(quark_run.Rtab == nan)
# Out:
# False

# %%
gluon_run.S
# Out:
# 0j

# %%
pts[-1][0].Gtab

# %%
plt.plot(qrange, 1 / (1 - qrange))
plt.plot(qrange, -1/qrange * log(1 - qrange))
# Out:
# /tmp/ipykernel_45215/3823240954.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(qrange, 1 / (1 - qrange))
# /tmp/ipykernel_45215/3823240954.py:2: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(qrange, -1/qrange * log(1 - qrange))
# /tmp/ipykernel_45215/3823240954.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(qrange, -1/qrange * log(1 - qrange))
# /tmp/ipykernel_45215/3823240954.py:2: RuntimeWarning: invalid value encountered in log
#   plt.plot(qrange, -1/qrange * log(1 - qrange))
# /tmp/ipykernel_45215/3823240954.py:2: RuntimeWarning: invalid value encountered in multiply
#   plt.plot(qrange, -1/qrange * log(1 - qrange))
