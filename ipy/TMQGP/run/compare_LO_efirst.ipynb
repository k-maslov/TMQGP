# %%
from numpy import *

# %%
import h5py

# %%
f1 = h5py.File('4ch_LO/data_single_199.hdf5')
f2 = h5py.File('4ch_LO_efirst/data_single_199.hdf5')

# %%
erange = f1.attrs['erange']

# %%
plt.plot(erange, f1['Q']['R'][:, 0])
plt.plot(erange, f2['Q']['R'][:, 0])

# %%
plt.plot(erange, imag(f1['TM']['qa1']['0'][:, 0]))
plt.plot(erange, imag(f2['TM']['qa1']['0'][:, 0]), ls=':')

# %%
th1 = h5py.File('4ch_LO/th_data_single_170.hdf5')
th2 = h5py.File('4ch_LO_efirst/th_data_single_170.hdf5')

# %%
th1.attrs['Ptot']
# Out:
# array([0.00069467])

# %%
th2.attrs['Ptot']
# Out:
# array([0.00069587])

# %%
th1.attrs['P_Q_Q']
# Out:
# array([0.00096332])

# %%
th2.attrs['P_Q_Q']
# Out:
# array([0.00096261])
